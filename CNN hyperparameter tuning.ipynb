# %%
import pandas as pd
from pandas import concat
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import backend as K
from keras.layers.convolutional import Conv2D, MaxPooling2D, AveragePooling2D

class AutoCNN():
    
    '''
    Vector Autoregression model

    Attributes
    ----------
    self.data_backup: dataframe, a backup copy of the input dataset
    self.data: dataframe, the main dataset worked on
    self.n: int, length (unit in months) of target to predict
    self.df_result: dataframe, stores the predicted target and the true target
    self.lag: int, number of past months used to predict the target
    self.rmse: rounded RMSE of the prediction
    self.target: str, name of target variable
    self.model: record a CNN trained model
    self.train_result: record model fit result loss
    
    Params
    ----------
    data_name: str, name of the dataset. Notice the input dataset must contain a column named 'Date'
    target_name: str, name of target variable
    drop_cols: list of strings, names of columns to drop
    '''
    def __init__(self, data_name, target_name, drop_cols=['Date']):   
        #import data
        curr_path = os.getcwd()
        input_path = os.path.join(curr_path, data_name)
        data = pd.read_excel(input_path, index_col=0)
        
        #drop columns and na
        data.drop(drop_cols, axis=1, inplace=True)
        data.dropna(inplace = True)
        # data.reset_index(drop=True, inplace=True)
        
        #set attributes
        self.data = data
        self.n = 0
        self.df_result = 0
        self.lag = 0
        self.column_name = []
        self.rmse = 0
        self.target = target_name
        self.n_features = len(data.columns) - 1
        self.model = 0
        self.train_result = 0
        
    def series_to_supervised(self, data, n_in=1, n_out=1, dropnan=True, if_target=True):
        n_vars = 1 if type(data) is list else data.shape[1]
        df = pd.DataFrame(data)
        df_without_target = df.loc[:, df.columns[1:]]
        cols, names = list(), list()
        if if_target:
            for i in range(n_in, 0, -1):
                cols.append(df.shift(i))
                names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
            for i in range(0, n_out):
                cols.append(df.shift(-i))
                if i == 0:
                    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
                else:
                    names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            agg = concat(cols, axis=1)
            agg.columns = names
        else:
            for i in range(n_in, 0, -1):
                cols.append(df_without_target.shift(i))
                names += [('var%d(t-%d)' % (j+1, i)) for j in range(1, n_vars)]
            for i in range(0, n_out):
                cols.append(df.shift(-i))
                if i == 0:
                    names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
                else:
                    names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            agg = concat(cols, axis=1)
            agg.columns = names
        if dropnan:
            agg.dropna(inplace=True)
        return agg
    

    def run(self, pred_begin_date, n, use_target=True, lags=3, leads=1): 
        ''' Run CNN
        
        Params
        ----------
        pred_begin_date: date, the begin date of prediction
        n: int, length of prediction (unit in months)      
        lag: int, num of past months to consider
        if_target: boolean, whether to include target as a predictor
        '''

        # normalize features
        scaler = MinMaxScaler(feature_range=(0, 1))
        scaled = scaler.fit_transform(self.data)
        # flatten data
        reframed = self.series_to_supervised(scaled, lags, leads, True, use_target)
        # drop columns we don't want to predict
        reframed.drop(reframed.columns[range(reframed.shape[1] - self.n_features, reframed.shape[1])], axis=1, inplace=True)
        reframed.drop(reframed.columns[range(reframed.shape[1] - 1 - (leads - 1) * (self.n_features + 1), reframed.shape[1]-1)], axis=1, inplace=True)
        
        values = reframed.values
        self.n = n

        test_date_begin = self.data.index.get_loc(pred_begin_date) - lags - leads + 1
        
        train = values[:test_date_begin, :]
        test = values[test_date_begin: test_date_begin+self.n, :]

        # split into input and outputs
        train_X, train_y = train[:, :-1], train[:, -1]
        test_X, test_y = test[:, :-1], test[:, -1]
                
        # reshape data and normalize data
        if use_target:
            features  = self.n_features+1
            train_X_reshaped = np.array(train_X).reshape(len(train_X), lags, self.n_features+1, 1)
            test_X_reshaped = np.array(test_X).reshape(len(test_X), lags, self.n_features+1, 1)
        else:
            features = self.n_features
            train_X_reshaped = np.array(train_X).reshape(len(train_X), lags, self.n_features, 1)
            test_X_reshaped = np.array(test_X).reshape(len(test_X), lags, self.n_features, 1)            

        #build CNN model
        model = Sequential()
        model.add(Conv2D(filters = 32, 
                         input_shape = ((lags, features, 1)),
                         data_format = 'channels_last',
                         kernel_size=(2,2), 
                         strides=(1,1),   
                         activation='relu'))
        #model.add(MaxPooling2D(pool_size=(2, 1)))
        #model.add(AveragePooling2D(pool_size=(2,1)))
        model.add(Flatten())
        model.add(Dense(45, activation='relu'))
        model.add(Dense(1))
        
        def root_mean_squared_error(y_true, y_pred):
            return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1))
        model.compile(optimizer='adam', loss=root_mean_squared_error)
        
        result = model.fit(train_X_reshaped, train_y, verbose=0, validation_data=(test_X_reshaped, test_y), epochs=20)
        self.model = model
        self.train_result = result
        
        pred_y = self.model.predict(test_X_reshaped)
        pred_y = pred_y.reshape((len(pred_y), 1))
        
        if use_target:
            inv_yhat = np.concatenate((pred_y, test_X[:, 1:features]), axis=1)
        else:
            inv_yhat = np.concatenate((pred_y, test_X[:, :features]), axis=1)
        
        inv_yhat = scaler.inverse_transform(inv_yhat)
        inv_yhat = inv_yhat[:,0]
        # invert scaling for actual

        test_y = test_y.reshape((len(test_y), 1))
        inv_y = np.concatenate((test_y, test_X[:, 1:self.n_features+1]), axis=1)
        inv_y = scaler.inverse_transform(inv_y)
        inv_y = inv_y[:,0]
        
        df_result = pd.DataFrame(inv_yhat, columns=[self.target + '_pred'])
        df_result[self.target] = inv_y
        df_result['Date'] = self.data.index[test_date_begin + lags+leads-1:  test_date_begin+lags+n+leads-1]
        df_result.set_index(['Date'],inplace=True)
        self.df_result=df_result
        
        # calculate RMSE
        rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
        print('Test RMSE: %.3f' % rmse)
        self.rmse = round(rmse,2)

# %%
cnn_model = AutoCNN(data_name='interaction_data_1107.xlsx', target_name='SP500-EPS-Index', drop_cols=[])
d = '2018-06-01 00:00:00'
n = 1
lag = 12
lead = 1
cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
plt.plot(cnn_model.train_result.history['loss'])
plt.plot(cnn_model.train_result.history['val_loss'])
# Out:
# Test RMSE: 21.354

# %%
lags = [12, 18, 24, 30, 36]
leadings = np.arange(1, 13)

cnn_model = AutoCNN(data_name='data_1107.xlsx', target_name='SP500-EPS-Index', drop_cols=[])
d = '2016-01-01 00:00:00'
n = 36
results = {}
results['opt_lag']=[]

for lead in leadings:
    results[lead] = []
    for lag in lags:
        print(f'lead: {lead}, lag: {lag}')
        cnn_temp = []
        cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
        cnn_temp.append(cnn_model.rmse)
        cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
        cnn_temp.append(cnn_model.rmse)
        cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
        cnn_temp.append(cnn_model.rmse)
        cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
        cnn_temp.append(cnn_model.rmse)
        cnn_model.run(pred_begin_date=d, n=n, use_target=True, lags=lag, leads=lead)
        cnn_temp.append(cnn_model.rmse)
        results[lead].append(np.average(cnn_temp))
    results['opt_lag'].append(np.argmin(results[lead])*6+12)
# Out:
# lead: 1, lag: 12
# Test RMSE: 86.631
# Test RMSE: 132.617
# Test RMSE: 200.086
# Test RMSE: 80.737
# Test RMSE: 73.943
# lead: 1, lag: 18
# Test RMSE: 107.519
# Test RMSE: 138.580
# Test RMSE: 198.916
# Test RMSE: 72.372
# Test RMSE: 90.608
# lead: 1, lag: 24
# Test RMSE: 126.649
# Test RMSE: 190.292
# Test RMSE: 172.808
# Test RMSE: 127.451
# Test RMSE: 115.428
# lead: 1, lag: 30
# Test RMSE: 126.892
# Test RMSE: 139.307
# Test RMSE: 1435.362
# Test RMSE: 1432.297
# Test RMSE: 79.519
# lead: 1, lag: 36
# Test RMSE: 115.249
# Test RMSE: 93.934
# Test RMSE: 221.677
# Test RMSE: 96.543
# Test RMSE: 140.388
# lead: 2, lag: 12
# Test RMSE: 69.334
# Test RMSE: 167.819
# Test RMSE: 125.549
# Test RMSE: 156.605
# Test RMSE: 125.104
# lead: 2, lag: 18
# Test RMSE: 134.465
# Test RMSE: 90.728
# Test RMSE: 1438.982
# Test RMSE: 101.205
# Test RMSE: 116.789
# lead: 2, lag: 24
# Test RMSE: 81.268
# Test RMSE: 1436.302
# Test RMSE: 128.860
# Test RMSE: 109.627
# Test RMSE: 129.604
# lead: 2, lag: 30
# Test RMSE: 83.576
# Test RMSE: 178.729
# Test RMSE: 94.445
# Test RMSE: 1434.849
# Test RMSE: 147.862
# lead: 2, lag: 36
# Test RMSE: 175.113
# Test RMSE: 177.425
# Test RMSE: 131.779
# Test RMSE: 133.204
# Test RMSE: 205.859
# lead: 3, lag: 12
# Test RMSE: 124.603
# Test RMSE: 129.396
# Test RMSE: 180.138
# Test RMSE: 148.269
# Test RMSE: 117.859
# lead: 3, lag: 18
# Test RMSE: 170.705
# Test RMSE: 154.364
# Test RMSE: 137.861
# Test RMSE: 134.612
# Test RMSE: 137.849
# lead: 3, lag: 24
# Test RMSE: 225.867
# Test RMSE: 204.837
# Test RMSE: 1436.331
# Test RMSE: 191.568
# Test RMSE: 120.292
# lead: 3, lag: 30
# Test RMSE: 117.792
# Test RMSE: 121.038
# Test RMSE: 130.747
# Test RMSE: 372.205
# Test RMSE: 1431.695
# lead: 3, lag: 36
# Test RMSE: 135.925
# Test RMSE: 1432.259
# Test RMSE: 125.579
# Test RMSE: 170.765
# Test RMSE: 129.256
# lead: 4, lag: 12
# Test RMSE: 127.963
# Test RMSE: 111.937
# Test RMSE: 74.735
# Test RMSE: 173.272
# Test RMSE: 110.724
# lead: 4, lag: 18
# Test RMSE: 171.124
# Test RMSE: 1440.320
# Test RMSE: 145.980
# Test RMSE: 113.390
# Test RMSE: 144.225
# lead: 4, lag: 24
# Test RMSE: 224.917
# Test RMSE: 136.243
# Test RMSE: 225.297
# Test RMSE: 136.500
# Test RMSE: 90.983
# lead: 4, lag: 30
# Test RMSE: 122.011
# Test RMSE: 111.165
# Test RMSE: 89.217
# Test RMSE: 172.237
# Test RMSE: 178.723
# lead: 4, lag: 36
# Test RMSE: 150.517
# Test RMSE: 170.424
# Test RMSE: 122.879
# Test RMSE: 197.005
# Test RMSE: 121.661
# lead: 5, lag: 12
# Test RMSE: 205.297
# Test RMSE: 130.497
# Test RMSE: 98.937
# Test RMSE: 128.858
# Test RMSE: 145.719
# lead: 5, lag: 18
# Test RMSE: 140.469
# Test RMSE: 1440.461
# Test RMSE: 97.935
# Test RMSE: 161.529
# Test RMSE: 175.045
# lead: 5, lag: 24
# Test RMSE: 107.625
# Test RMSE: 198.678
# Test RMSE: 1433.687
# Test RMSE: 1434.775
# Test RMSE: 71.720
# lead: 5, lag: 30
# Test RMSE: 152.281
# Test RMSE: 160.806
# Test RMSE: 123.357
# Test RMSE: 161.284
# Test RMSE: 135.896
# lead: 5, lag: 36
# Test RMSE: 151.459
# Test RMSE: 147.745
# Test RMSE: 98.753
# Test RMSE: 177.855
# Test RMSE: 167.166
# lead: 6, lag: 12
# Test RMSE: 187.572
# Test RMSE: 164.737
# Test RMSE: 190.122
# Test RMSE: 264.686
# Test RMSE: 109.665
# lead: 6, lag: 18
# Test RMSE: 194.987
# Test RMSE: 177.494
# Test RMSE: 196.402
# Test RMSE: 226.007
# Test RMSE: 154.864
# lead: 6, lag: 24
# Test RMSE: 232.876
# Test RMSE: 164.235
# Test RMSE: 158.284
# Test RMSE: 152.441
# Test RMSE: 174.093
# lead: 6, lag: 30
# Test RMSE: 164.462
# Test RMSE: 139.202
# Test RMSE: 106.488
# Test RMSE: 1430.272
# Test RMSE: 1429.219
# lead: 6, lag: 36
# Test RMSE: 132.668
# Test RMSE: 156.671
# Test RMSE: 148.740
# Test RMSE: 1432.291
# Test RMSE: 187.662
# lead: 7, lag: 12
# Test RMSE: 161.738
# Test RMSE: 179.697
# Test RMSE: 200.233
# Test RMSE: 163.666
# Test RMSE: 220.742
# lead: 7, lag: 18
# Test RMSE: 155.292
# Test RMSE: 99.312
# Test RMSE: 117.068
# Test RMSE: 140.298
# Test RMSE: 251.999
# lead: 7, lag: 24
# Test RMSE: 221.578
# Test RMSE: 151.692
# Test RMSE: 181.783
# Test RMSE: 91.030
# Test RMSE: 81.403
# lead: 7, lag: 30
# Test RMSE: 217.656
# Test RMSE: 152.004
# Test RMSE: 100.590
# Test RMSE: 150.774
# Test RMSE: 1431.861
# lead: 7, lag: 36
# Test RMSE: 107.134
# Test RMSE: 1427.452
# Test RMSE: 1420.549
# Test RMSE: 167.066
# Test RMSE: 137.279
# lead: 8, lag: 12
# Test RMSE: 192.379
# Test RMSE: 216.208
# Test RMSE: 134.536
# Test RMSE: 194.941
# Test RMSE: 175.059
# lead: 8, lag: 18
# Test RMSE: 285.371
# Test RMSE: 211.444
# Test RMSE: 192.853
# Test RMSE: 184.122
# Test RMSE: 173.054
# lead: 8, lag: 24
# Test RMSE: 193.317
# Test RMSE: 1433.182
# Test RMSE: 1431.885
# Test RMSE: 196.536
# Test RMSE: 297.663
# lead: 8, lag: 30
# Test RMSE: 125.216
# Test RMSE: 137.015
# Test RMSE: 150.066
# Test RMSE: 172.319
# Test RMSE: 143.419
# lead: 8, lag: 36
# Test RMSE: 1421.831
# Test RMSE: 160.877
# Test RMSE: 1419.344
# Test RMSE: 173.992
# Test RMSE: 179.429
# lead: 9, lag: 12
# Test RMSE: 272.396
# Test RMSE: 182.417
# Test RMSE: 256.062
# Test RMSE: 271.895
# Test RMSE: 267.159
# lead: 9, lag: 18
# Test RMSE: 202.106
# Test RMSE: 211.191
# Test RMSE: 147.283
# Test RMSE: 91.220
# Test RMSE: 156.166
# lead: 9, lag: 24
# Test RMSE: 90.465
# Test RMSE: 182.295
# Test RMSE: 203.340
# Test RMSE: 174.729
# Test RMSE: 129.049
# lead: 9, lag: 30
# Test RMSE: 149.439
# Test RMSE: 196.380
# Test RMSE: 148.091
# Test RMSE: 1426.153
# Test RMSE: 238.949
# lead: 9, lag: 36
# Test RMSE: 164.354
# Test RMSE: 145.157
# Test RMSE: 136.810
# Test RMSE: 191.060
# Test RMSE: 183.342
# lead: 10, lag: 12
# Test RMSE: 196.596
# Test RMSE: 138.100
# Test RMSE: 172.207
# Test RMSE: 161.675
# Test RMSE: 185.214
# lead: 10, lag: 18
# Test RMSE: 240.225
# Test RMSE: 260.476
# Test RMSE: 127.599
# Test RMSE: 1435.375
# Test RMSE: 1435.682
# lead: 10, lag: 24
# Test RMSE: 181.318
# Test RMSE: 282.137
# Test RMSE: 310.554
# Test RMSE: 218.101
# Test RMSE: 223.797
# lead: 10, lag: 30
# Test RMSE: 209.469
# Test RMSE: 141.506
# Test RMSE: 171.088
# Test RMSE: 157.915
# Test RMSE: 180.940
# lead: 10, lag: 36
# Test RMSE: 177.087
# Test RMSE: 246.930
# Test RMSE: 163.025
# Test RMSE: 174.834
# Test RMSE: 133.595
# lead: 11, lag: 12
# Test RMSE: 249.621
# Test RMSE: 254.823
# Test RMSE: 201.496
# Test RMSE: 292.371
# Test RMSE: 225.617
# lead: 11, lag: 18
# Test RMSE: 1434.488
# Test RMSE: 124.219
# Test RMSE: 249.103
# Test RMSE: 141.471
# Test RMSE: 217.250
# lead: 11, lag: 24
# Test RMSE: 149.210
# Test RMSE: 198.112
# Test RMSE: 122.399
# Test RMSE: 230.487
# Test RMSE: 97.641
# lead: 11, lag: 30
# Test RMSE: 1427.883
# Test RMSE: 137.757
# Test RMSE: 66.899
# Test RMSE: 178.849
# Test RMSE: 1429.644
# lead: 11, lag: 36
# Test RMSE: 154.306
# Test RMSE: 186.267
# Test RMSE: 188.599
# Test RMSE: 162.121
# Test RMSE: 167.726
# lead: 12, lag: 12
# Test RMSE: 223.375
# Test RMSE: 146.630
# Test RMSE: 193.576
# Test RMSE: 146.911
# Test RMSE: 249.272
# lead: 12, lag: 18
# Test RMSE: 171.265
# Test RMSE: 177.001
# Test RMSE: 248.361
# Test RMSE: 191.916
# Test RMSE: 195.206
# lead: 12, lag: 24
# Test RMSE: 179.471
# Test RMSE: 160.016
# Test RMSE: 174.081
# Test RMSE: 144.375
# Test RMSE: 98.964
# lead: 12, lag: 30
# Test RMSE: 236.165
# Test RMSE: 166.928
# Test RMSE: 200.544
# Test RMSE: 169.482
# Test RMSE: 160.272
# lead: 12, lag: 36
# Test RMSE: 150.346
# Test RMSE: 229.705
# Test RMSE: 1424.709
# Test RMSE: 226.943
# Test RMSE: 1422.865

# %%
results['opt_lag']
# Out:
# [12, 12, 12, 12, 12, 24, 24, 30, 24, 12, 24, 24]

# %%
results
# Out:
# {'opt_lag': [12, 12, 12, 12, 12, 24, 24, 30, 24, 12, 24, 24],
#  1: [114.804, 121.6, 146.526, 642.6759999999999, 133.558],
#  2: [128.882, 376.434, 377.13199999999995, 387.892, 164.676],
#  3: [140.054, 147.07800000000003, 435.78000000000003, 434.696, 398.758],
#  4: [119.726, 403.00600000000003, 162.788, 134.672, 152.498],
#  5: [141.864, 403.088, 649.296, 146.726, 148.596],
#  6: [183.35600000000002,
#   189.95,
#   176.386,
#   653.9280000000001,
#   411.60599999999994],
#  7: [185.21599999999998,
#   152.794,
#   145.49599999999998,
#   410.576,
#   651.8960000000001],
#  8: [182.62599999999998,
#   209.36599999999999,
#   710.516,
#   145.608,
#   671.0939999999999],
#  9: [249.98799999999997,
#   161.594,
#   155.97400000000002,
#   431.80199999999996,
#   164.144],
#  10: [170.76, 699.8700000000001, 243.18200000000002, 172.186, 179.092],
#  11: [244.786, 433.3059999999999, 159.57, 648.206, 171.806],
#  12: [191.954, 196.75, 151.38000000000002, 186.676, 690.914]}
